# %%
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-61e0adcaee13> in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_json("reviews.jl", lines=True)

# %%
df.shape[0]
# Out:
# 1375356

# %%
df[df['rating'].isin(['1','2','3','4','5'])]
# Out:
#                     company_name            company_website  \
# 0             Paw Print Genetics       pawprintgenetics.com
# 1             Paw Print Genetics       pawprintgenetics.com
# 8             Paw Print Genetics       pawprintgenetics.com
# 9             Paw Print Genetics       pawprintgenetics.com
# 12            Paw Print Genetics       pawprintgenetics.com
# ...                          ...                        ...
# 1375351  Envision Video Services  envisionvideoservices.com
# 1375352  Envision Video Services  envisionvideoservices.com
# 1375353  Envision Video Services  envisionvideoservices.com
# 1375354  Envision Video Services  envisionvideoservices.com
# 1375355  Envision Video Services  envisionvideoservices.com
#
#                                               company_logo  \
# 0        //s3-eu-west-1.amazonaws.com/tpd/logos/598213b...
# 1        //s3-eu-west-1.amazonaws.com/tpd/logos/598213b...
# 8        //s3-eu-west-1.amazonaws.com/tpd/logos/598213b...
# ...

# %%
data = df.iloc[:1000,:]

# %%
data
# Out:
#                                           company_name       company_website  \
# 0                                   Paw Print Genetics  pawprintgenetics.com
# 1                                   Paw Print Genetics  pawprintgenetics.com
# 2                                   Paw Print Genetics  pawprintgenetics.com
# 3                                   Paw Print Genetics  pawprintgenetics.com
# 4                                   Paw Print Genetics  pawprintgenetics.com
# ..                                                 ...                   ...
# 995  Pawshake | Dog sitting, Cat sitting, Pet Sitti...          pawshake.com
# 996  Pawshake | Dog sitting, Cat sitting, Pet Sitti...          pawshake.com
# 997                                  The Mindful Habit   themindfulhabit.com
# 998                                  The Mindful Habit   themindfulhabit.com
# 999                                  The Mindful Habit   themindfulhabit.com
#
# ...

# %%
data[data['rating'].isin(['1','2','3','4','5'])]
# Out:
#                                           company_name       company_website  \
# 0                                   Paw Print Genetics  pawprintgenetics.com
# 1                                   Paw Print Genetics  pawprintgenetics.com
# 8                                   Paw Print Genetics  pawprintgenetics.com
# 9                                   Paw Print Genetics  pawprintgenetics.com
# 12                                  Paw Print Genetics  pawprintgenetics.com
# ..                                                 ...                   ...
# 995  Pawshake | Dog sitting, Cat sitting, Pet Sitti...          pawshake.com
# 996  Pawshake | Dog sitting, Cat sitting, Pet Sitti...          pawshake.com
# 997                                  The Mindful Habit   themindfulhabit.com
# 998                                  The Mindful Habit   themindfulhabit.com
# 999                                  The Mindful Habit   themindfulhabit.com
#
# ...

# %%
df.groupby('subcategory').agg('count')
# Out:
#                      category  company_name  company_uri
# subcategory
# Animal Health              12            12           12
# Animal Parks & Zoo          2             2            2
# Cats & Dogs                12            12           12
# Cosmetics & Makeup        203           203          203
# Hair Care & Styling        91            91           91
# Horses & Riding             6             6            6
# Personal Care             384           384          384
# Pet Services               17            17           17
# Pet Stores                206           206          206
# Salons & Clinics          160           160          160
